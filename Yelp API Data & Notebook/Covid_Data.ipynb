# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas import json_normalize

# %%
for i in range(0,1000,50):
    print(i)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
frames=[]

for i in range(0,1000,50):

    url = "https://api.yelp.com/v3/businesses/search?location=charlotte&offset="+str(i)+"&limit=50"

    api_key = "CzlK_Ax6avC-DOL7xD8-e8e-X4-ga2DQMGwV0XYS0b3ae939gNAelzDfarNXhz-ZMIBOyOuiOcOiKTya6j7MLw7pkhK1WxDndC6MbJfszdZk9HXrDKvNCQN2BN2uYHYx"

    header = {"Authorization": "Bearer {}".format(api_key)}

    response = requests.get(url, headers = header)

    yelp_data = response.json()
    recs = yelp_data["businesses"]
    df = json_normalize(recs)

    yelpDF = pd.DataFrame(df)

    frames.append(yelpDF)
    #print(i)

    #print(json.dumps(yelp_data, indent=4, sort_keys=True))
    
yelpDF=pd.concat(frames)
yelpDF
# Out:
#                         id                                        alias  \
# 0   RVQE2Z2uky4c0-njFQO66g                 midwood-smokehouse-charlotte
# 1   RAh9WCQAuocM7hYM5_6tnw       the-cowfish-sushi-burger-bar-charlotte
# 2   sdYkVaTy7EJwUkO8Ie_qPg                       viva-chicken-charlotte
# 3   gG9z6zr_49LocyCTvSFg0w  amélies-french-bakery-and-café-charlotte-11
# 4   NFm869_w6cvVaWaNpAzjeA                  soul-gastrolounge-charlotte
# ..                     ...                                          ...
# 45  J2r0m1mHPT8VlpKVxPnr1g                               orto-charlotte
# 46  8HYtFglLCaGUpd4iSZFAkg         brakemans-coffee-and-supply-matthews
# 47  1rFy8c2Pv4sDb-fcf3FMFQ                          small-bar-charlotte
# 48  ntMauFOy3bpFqrYG7n0v2Q                     chicken-king-charlotte-4
# 49  KI47XMlkhP0L--rzqtTQ8w                          bargarita-charlotte
#
#                              name  \
# 0              Midwood Smokehouse
# 1    The Cowfish Sushi Burger Bar
# 2                    Viva Chicken
# 3   Amélie's French Bakery & Café
# 4               Soul Gastrolounge
# ..                            ...
# 45                           Orto
# 46     Brakeman's Coffee & Supply
# 47                      Small Bar
# 48                   Chicken King
# 49                      Bargarita
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/CGN1sN...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/g7R1om...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/2C1fmF...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/k-DCr0...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/vFPlCR...      False
# ..                                                ...        ...
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/vamYcU...      False
# 46  https://s3-media1.fl.yelpcdn.com/bphoto/79nq2F...      False
# 47  https://s3-media3.fl.yelpcdn.com/bphoto/xVU2Ts...      False
# 48  https://s3-media3.fl.yelpcdn.com/bphoto/yPInxW...      False
# 49  https://s3-media4.fl.yelpcdn.com/bphoto/uKHA7q...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/midwood-smokehouse-ch...          1985
# 1   https://www.yelp.com/biz/the-cowfish-sushi-bur...          1911
# 2   https://www.yelp.com/biz/viva-chicken-charlott...          1000
# 3   https://www.yelp.com/biz/am%C3%A9lies-french-b...          1890
# 4   https://www.yelp.com/biz/soul-gastrolounge-cha...          1154
# ..                                                ...           ...
# 45  https://www.yelp.com/biz/orto-charlotte?adjust...            26
# 46  https://www.yelp.com/biz/brakemans-coffee-and-...            98
# 47  https://www.yelp.com/biz/small-bar-charlotte?a...            40
# 48  https://www.yelp.com/biz/chicken-king-charlott...            18
# 49  https://www.yelp.com/biz/bargarita-charlotte?a...            40
#
#                                            categories  rating  \
# 0   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 2        [{'alias': 'peruvian', 'title': 'Peruvian'}]     4.5
# 3   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
# 4   [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...     4.0
# ..                                                ...     ...
# 45  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 46  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 47               [{'alias': 'bars', 'title': 'Bars'}]     3.0
# 48  [{'alias': 'chicken_wings', 'title': 'Chicken ...     4.0
# 49  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     3.5
#
#           transactions  ... coordinates.latitude coordinates.longitude  \
# 0   [delivery, pickup]  ...            35.220920            -80.814850
# 1   [pickup, delivery]  ...            35.152725            -80.827953
# 2   [pickup, delivery]  ...            35.213421            -80.826022
# 3           [delivery]  ...            35.241145            -80.812057
# 4           [delivery]  ...            35.220180            -80.813290
# ..                 ...  ...                  ...                   ...
# 45                  []  ...            35.248523            -80.805414
# 46          [delivery]  ...            35.117871            -80.721030
# 47                  []  ...            35.238557            -80.844381
# 48  [pickup, delivery]  ...            35.233181            -80.807693
# 49          [delivery]  ...            35.247610            -80.805024
#
#      location.address1  location.address2  location.address3  location.city  \
# 0     1401 Central Ave                                            Charlotte
# 1       4310 Sharon Rd            Ste X05                         Charlotte
# 2   1617 Elizabeth Ave               None                         Charlotte
# 3   2424 N Davidson St            Ste 102                         Charlotte
# 4   1500-B Central Ave                                            Charlotte
# ..                 ...                ...                ...            ...
# 45       416 E 36th St               None               None      Charlotte
# 46      225 N Trade St                                  None       Matthews
# 47     900 Seaboard St                                            Charlotte
# 48        2301 The Plz               None               None      Charlotte
# 49  3221 N Davidson St                                  None      Charlotte
#
#    location.zip_code location.country location.state  \
# 0              28205               US             NC
# 1              28211               US             NC
# 2              28204               US             NC
# 3              28205               US             NC
# 4              28205               US             NC
# ..               ...              ...            ...
# 45             28205               US             NC
# 46             28105               US             NC
# 47             28206               US             NC
# 48             28205               US             NC
# 49             28205               US             NC
#
#                              location.display_address
# 0             [1401 Central Ave, Charlotte, NC 28205]
# 1      [4310 Sharon Rd, Ste X05, Charlotte, NC 28211]
# 2           [1617 Elizabeth Ave, Charlotte, NC 28204]
# 3   [2424 N Davidson St, Ste 102, Charlotte, NC 28...
# 4           [1500-B Central Ave, Charlotte, NC 28205]
# ..                                                ...
# 45               [416 E 36th St, Charlotte, NC 28205]
# 46               [225 N Trade St, Matthews, NC 28105]
# 47             [900 Seaboard St, Charlotte, NC 28206]
# 48                [2301 The Plz, Charlotte, NC 28205]
# 49          [3221 N Davidson St, Charlotte, NC 28205]
#
# [1000 rows x 24 columns]

# %%
#yelpDF["categories"][0]

# %%
response = requests.get(url, headers = header)
data = response.json()['businesses']
alias = []
business_id = []
city = []
is_closed = []
rating = []
categories = []


for i in range(len(data)):
    alias.append(data[i]["alias"])
    business_id.append(data[i]["id"])
    city.append(data[i]["location"]["city"])
    is_closed.append(data[i]["is_closed"])
    rating.append(data[i]["rating"])
    categories.append(data[i]["categories"][0]["alias"])
    
columns = {"Restaurant Name": alias, "business_id": business_id, "City": city, "Closed": is_closed, "Rating": rating, "Category": categories}

restaurantDF = pd.DataFrame(columns)

restaurantDF
# Out:
#                                       Restaurant Name             business_id  \
# 0             us-foods-chef-store-charlotte-charlotte  oksJBFEjT78mYpkVDfyQdw
# 1                           the-cooking-pot-charlotte  kSBsGa6sUd9sBf1WPFHn-A
# 2              fat-cat-burgers-and-bakeshop-charlotte  YceMesD84tTovXlp_8Y-Ww
# 3                      outback-steakhouse-charlotte-2  K8-LLbISfbE9ObRcshKFpg
# 4           fuji-hibachi-and-teriyaki-grill-charlotte  Jo6EcTFYMMFbbdmkSPG5ug
# 5                              sandwich-sam-charlotte  6R3YPIg3xTHqHAK5qk_KnQ
# 6                              starbucks-charlotte-45  Rx6PF3O6Q8pJz8dLMJZfKQ
# 7                    showmars-little-rock-charlotte-2  wh62Gu_Wgnti9W_WAY-nHQ
# 8                ribbonwalk-nature-preserve-charlotte  EvkOWH4GpKjyQjigAJcraA
# 9                 felixs-handmade-empanadas-charlotte  BmMnCBNJJr0gIAZ4sh4n9A
# 10                 pressley-park-restaurant-charlotte  03fe5vYwHA9TxlJJ-7mDMw
# 11                           panera-bread-charlotte-8  H49dwF7meLTuP0haqIhHCA
# 12                                 skiptown-charlotte  vPNFWeWl8qW6oWzLjFVrrw
# 13                          kre8-xperiences-charlotte  BWJEU3H4rP0RHNO6Ywv0Pw
# 14      the-vintage-whiskey-and-cigar-bar-charlotte-2  DrcF8IhaQ83mlwKFb3cePg
# 15                               subway-charlotte-125  cV-mgaEpAWY7w95fRZi8SQ
# 16                   pure-intentions-coffee-charlotte  Q3ihaXT-akQN_2SKGhkw1Q
# 17                                 quiktrip-charlotte  r3ATwPjhjcw-zk6wPl4KnA
# 18                                 zen-taco-charlotte  UPjIiLldv0TD6y87fDofzg
# 19                 free-will-craft-and-vine-charlotte  3mMxXqjsdQFgL14E-NCNDA
# 20                              chick-fil-a-charlotte  9od7WQ6N7xwpUnGWu7J01Q
# 21                                  wu-rons-charlotte  IiCxnNNF-g4VMNi1DfCCcA
# 22                              starbucks-charlotte-9  Gsbt1IoWkjrh9nExM7BIFw
# 23                           chicken-king-charlotte-5  TI81U-Fij4uNhd06aMb3qQ
# 24                       the-pub-at-gateway-charlotte  PZngIVXHzqnqOS1E7HWGYg
# 25                               flagstones-charlotte  HBBZRHpJG3L4lXLWz910JQ
# 26  kabuto-japanese-steak-house-and-sushi-bar-char...  VWJ5ek9uX-VFsD9Tiy2Njw
# 27                       marketplace-cafe-charlotte-5  ZibctB6IfQhvZJuq8W-OmA
# 28              paper-plane-deli-and-market-charlotte  C2veQL0JHnibpIwUTZ_EgA
# 29                    uptown-bar-and-lounge-charlotte  5V9i2FuhQ3o8ynYwbubmQg
# 30                     buffalo-wild-wings-charlotte-4  FTKxYJj7d5u3GiEHG5cQSQ
# 31                   square-peg-charlotte-charlotte-2  5Ikn6R8XNBf-DSPW-TLbxg
# 32                                   pudina-charlotte  0htWficVWZV20ATE8cs7YA
# 33                            bun-appetit-charlotte-3  B1R2tzy42bggyCabF9xtBw
# 34                  johns-family-restaurant-charlotte  _sf5MgDqH9P5OnK3tsHfkg
# 35                  mugshots-coffee-and-tea-charlotte  gt9n_dEz3_sqE-sYO9_qew
# 36                          the-spindle-bar-charlotte  eEY9ngQu3lLcFbuzqtHAzg
# 37                             taste-cafe-charlotte-2  V-qDa2kr5qWdhs7PU-l-3Q
# 38                                great-wok-charlotte  KxqAQ-CJcAPDTJbrnQUTfg
# 39  zaxbys-chicken-fingers-and-buffalo-wings-charl...  h0KYR6oAMRQh-Heh6GKMbQ
# 40                                  counter-charlotte  r2zPiNXZzqe7n_eiffSprg
# 41                                 xiao-bao-charlotte  i5rXG6os2dPhQ68nffeRdg
# 42                                   portal-charlotte  3u3B4z6MdkrzbdwfmL9n0w
# 43                showmars-seventh-street-charlotte-2  TreYsBGjXptogQQmQh1-bg
# 44                         taqueria-express-charlotte  8YyBAyA3TKpaVxy99FRWjA
# 45                                     orto-charlotte  J2r0m1mHPT8VlpKVxPnr1g
# 46               brakemans-coffee-and-supply-matthews  8HYtFglLCaGUpd4iSZFAkg
# 47                                small-bar-charlotte  1rFy8c2Pv4sDb-fcf3FMFQ
# 48                           chicken-king-charlotte-4  ntMauFOy3bpFqrYG7n0v2Q
# 49                                bargarita-charlotte  KI47XMlkhP0L--rzqtTQ8w
#
#          City  Closed  Rating          Category
# 0   Charlotte   False     4.0  wholesale_stores
# 1   Charlotte   False     3.5           african
# 2   Charlotte   False     4.5           burgers
# 3   Charlotte   False     2.5             steak
# 4   Charlotte   False     3.0          japanese
# 5   Charlotte   False     3.0        sandwiches
# 6   Charlotte   False     3.0            coffee
# 7   Charlotte   False     3.0             greek
# 8   Charlotte   False     4.0             parks
# 9   Charlotte   False     3.5         empanadas
# 10  Charlotte   False     3.5  breakfast_brunch
# 11  Charlotte   False     3.0              soup
# 12  Charlotte   False     4.0         dog_parks
# 13  Charlotte   False     4.0        gastropubs
# 14  Charlotte   False     4.5         cigarbars
# 15  Charlotte   False     4.0        sandwiches
# 16  Charlotte   False     5.0  coffeeroasteries
# 17  Charlotte   False     4.5   servicestations
# 18  Charlotte   False     4.5       asianfusion
# 19  Charlotte   False     5.0           beerbar
# 20  Charlotte   False     3.5           hotdogs
# 21  Charlotte   False     5.0             ramen
# 22  Charlotte   False     3.0            coffee
# 23  Charlotte   False     4.0           burgers
# 24  Charlotte   False     3.5     beer_and_wine
# 25  Charlotte   False     4.0      tradamerican
# 26  Charlotte   False     2.5          japanese
# 27  Charlotte   False     3.5       newamerican
# 28  Charlotte   False     4.5         wine_bars
# 29  Charlotte   False     3.0       newamerican
# 30  Charlotte   False     2.0     chicken_wings
# 31  Charlotte   False     4.5        foodtrucks
# 32  Charlotte   False     3.0             pizza
# 33  Charlotte   False     5.0          bakeries
# 34  Charlotte   False     3.5      tradamerican
# 35  Charlotte   False     5.0            coffee
# 36  Charlotte   False     3.5      cocktailbars
# 37  Charlotte   False     3.0  breakfast_brunch
# 38  Charlotte   False     2.5           chinese
# 39  Charlotte   False     3.0           hotdogs
# 40  Charlotte   False     4.5       newamerican
# 41  Charlotte   False     4.0          panasian
# 42  Charlotte   False     4.0        artmuseums
# 43  Charlotte   False     3.0             greek
# 44  Charlotte   False     3.5           mexican
# 45  Charlotte   False     4.0           italian
# 46   Matthews   False     4.5            coffee
# 47  Charlotte   False     3.0              bars
# 48  Charlotte   False     4.0     chicken_wings
# 49  Charlotte   False     3.5             tacos

# %%
covid_df = pd.read_csv('/Users/kylethomasmataloni/Desktop/covidrestaurant.csv')
covid_df

# %%
# data_file = open("yelp_academic_dataset_covid_features.json")
# data = []
# for line in data_file:
#     data.append(json.loads(line))
    
# covid_df = pd.DataFrame(data)

# data_file.close()

# covid_df

# %%
merge_df = pd.merge(restaurantDF, covid_df, on="business_id", how="right")
merge_df

# %%
RestaurantNotNull = pd.notnull(merge_df["Restaurant Name"])
merge_df[RestaurantNotNull]
