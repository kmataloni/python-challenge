# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas import json_normalize

# %%
#for i in range(0,1000,50):
    #print(i)

# %%
frames=[]

for i in range(0,1000,50):

    url = "https://api.yelp.com/v3/businesses/search?location=charlotte&offset="+str(i)+"&limit=50"

    api_key = "CzlK_Ax6avC-DOL7xD8-e8e-X4-ga2DQMGwV0XYS0b3ae939gNAelzDfarNXhz-ZMIBOyOuiOcOiKTya6j7MLw7pkhK1WxDndC6MbJfszdZk9HXrDKvNCQN2BN2uYHYx"

    header = {"Authorization": "Bearer {}".format(api_key)}

    response = requests.get(url, headers = header)

    yelp_data = response.json()
    recs = yelp_data["businesses"]
    df = json_normalize(recs)

    yelpDF = pd.DataFrame(df)

    frames.append(yelpDF)
    #print(i)

    #print(json.dumps(yelp_data, indent=4, sort_keys=True))
    
yelpDF1=pd.concat(frames)
yelpDF1

# %%
yelpDF1 = yelpDF1.reset_index(drop = True)
yelpDF1

# %%
frames=[]

for i in range(0,1000,50):

    url = "https://api.yelp.com/v3/businesses/search?location=pittsburg&offset="+str(i)+"&limit=50"

    api_key = "CzlK_Ax6avC-DOL7xD8-e8e-X4-ga2DQMGwV0XYS0b3ae939gNAelzDfarNXhz-ZMIBOyOuiOcOiKTya6j7MLw7pkhK1WxDndC6MbJfszdZk9HXrDKvNCQN2BN2uYHYx"

    header = {"Authorization": "Bearer {}".format(api_key)}

    response = requests.get(url, headers = header)

    yelp_data = response.json()
    recs = yelp_data["businesses"]
    df = json_normalize(recs)

    yelpDF = pd.DataFrame(df)

    frames.append(yelpDF)
    #print(i)

    #print(json.dumps(yelp_data, indent=4, sort_keys=True))
    
yelpDF2=pd.concat(frames)
yelpDF2
# Out:
#                         id                                alias  \
# 0   G9fBVf3Jkzf6_WXdZbtaaw                blue-saigon-pittsburg
# 1   omHQI6-Q65ql7JVWElFscQ            creasian-bistro-pittsburg
# 2   HZHC9JImMG5gj3-QTFzZIg         starbread-bakery-pittsburg-2
# 3   omGi-gmogVl7jDU1Pzh4yQ   skyview-noodle-and-tea-pittsburg-3
# 4   n6B6WS_EJU1qenwn-ksSPQ   steeltown-coffee-and-tea-pittsburg
# ..                     ...                                  ...
# 45  XfUP79vWojA9t1DsmUm3zw  mariachi-mexican-grill-walnut-creek
# 46  qu__sVreHnPO6-r87ZyjaA             jade-garden-walnut-creek
# 47  Ca-2am1xKVFO6vAWyRU2bw          cold-stone-creamery-antioch
# 48  c8DZTX7BR18FGkZ1S82BPQ          boston-market-pleasant-hill
# 49  s9mp5f6i8Mr1q_5bRaeJYw             adorubowl-walnut-creek-2
#
#                       name                                          image_url  \
# 0              Blue Saigon  https://s3-media2.fl.yelpcdn.com/bphoto/5N7Dc8...
# ...

# %%
yelpDF2 = yelpDF2.reset_index(drop = True)
yelpDF2

# %%
frames=[]

for i in range(0,1000,50):

    url = "https://api.yelp.com/v3/businesses/search?location=phoenix&offset="+str(i)+"&limit=50"

    api_key = "CzlK_Ax6avC-DOL7xD8-e8e-X4-ga2DQMGwV0XYS0b3ae939gNAelzDfarNXhz-ZMIBOyOuiOcOiKTya6j7MLw7pkhK1WxDndC6MbJfszdZk9HXrDKvNCQN2BN2uYHYx"

    header = {"Authorization": "Bearer {}".format(api_key)}

    response = requests.get(url, headers = header)

    yelp_data = response.json()
    recs = yelp_data["businesses"]
    df = json_normalize(recs)

    yelpDF = pd.DataFrame(df)

    frames.append(yelpDF)
    #print(i)

    #print(json.dumps(yelp_data, indent=4, sort_keys=True))
    
yelpDF3=pd.concat(frames)
yelpDF3
# Out:
#                         id                                          alias  \
# 0   VyVIneSU7XAWgMBllI6LnQ                             bobby-q-phoenix-12
# 1   Xg5qEQiB-7L6kGJ5F4K3bQ             little-miss-bbq-university-phoenix
# 2   PtJ02ZaHGB7yQxMHI7hDMw                        novel-ice-cream-phoenix
# 3   E4JyAzB5_2quptwtemyhYA               original-breakfast-house-phoenix
# 4   S-oLPRdhlyL5HAknBKTUcQ                  harumi-sushi-and-sake-phoenix
# ..                     ...                                            ...
# 45  p_V8gH43zZx0Gh_EA__hdg                          bosa-donuts-phoenix-7
# 46  -LbNfYuwyvTDFjh7TFygug  la-madeleine-french-bakery-and-cafe-phoenix-4
# 47  0TBTV3q6QXCn9vNhy3Xi2w                          café-lalibela-tempe-2
# 48  irYAkavSVtIEyGOsHK-yPw                              palette-phoenix-4
# 49  GGc72-G2GsrTuz8sz-kMGg             shaw-butte-recreation-area-phoenix
#
#                                  name  \
# 0                             Bobby Q
# ...

# %%
yelpDF3 = yelpDF3.reset_index(drop = True)
yelpDF3
# Out:
#                          id                                          alias  \
# 0    VyVIneSU7XAWgMBllI6LnQ                             bobby-q-phoenix-12
# 1    Xg5qEQiB-7L6kGJ5F4K3bQ             little-miss-bbq-university-phoenix
# 2    PtJ02ZaHGB7yQxMHI7hDMw                        novel-ice-cream-phoenix
# 3    E4JyAzB5_2quptwtemyhYA               original-breakfast-house-phoenix
# 4    S-oLPRdhlyL5HAknBKTUcQ                  harumi-sushi-and-sake-phoenix
# ..                      ...                                            ...
# 995  p_V8gH43zZx0Gh_EA__hdg                          bosa-donuts-phoenix-7
# 996  -LbNfYuwyvTDFjh7TFygug  la-madeleine-french-bakery-and-cafe-phoenix-4
# 997  0TBTV3q6QXCn9vNhy3Xi2w                          café-lalibela-tempe-2
# 998  irYAkavSVtIEyGOsHK-yPw                              palette-phoenix-4
# 999  GGc72-G2GsrTuz8sz-kMGg             shaw-butte-recreation-area-phoenix
#
#                                   name  \
# ...

# %%
frames=[]

for i in range(0,1000,50):

    url = "https://api.yelp.com/v3/businesses/search?location=lasvegas&offset="+str(i)+"&limit=50"

    api_key = "CzlK_Ax6avC-DOL7xD8-e8e-X4-ga2DQMGwV0XYS0b3ae939gNAelzDfarNXhz-ZMIBOyOuiOcOiKTya6j7MLw7pkhK1WxDndC6MbJfszdZk9HXrDKvNCQN2BN2uYHYx"

    header = {"Authorization": "Bearer {}".format(api_key)}

    response = requests.get(url, headers = header)

    yelp_data = response.json()
    recs = yelp_data["businesses"]
    df = json_normalize(recs)

    yelpDF = pd.DataFrame(df)

    frames.append(yelpDF)
    #print(i)

    #print(json.dumps(yelp_data, indent=4, sort_keys=True))
    
yelpDF4=pd.concat(frames)
yelpDF4

# %%
yelpDF4 = yelpDF4.reset_index(drop = True)
yelpDF4
# Out:
#                          id                                           alias  \
# 0    faPVqws-x-5k2CQKDNtHxw     yardbird-southern-table-and-bar-las-vegas-2
# 1    4JNXUYY8wbaaDmk3BPzlWw                        mon-ami-gabi-las-vegas-2
# 2    vHz2RLtfUMVRPFmd7VBEHA         gordon-ramsay-hells-kitchen-las-vegas-3
# 3    3kdSl5mo9dWC4clrQjEDGg                             egg-and-i-las-vegas
# 4    hihud--QRriCYZw1zZvW4g            gangnam-asian-bbq-dining-las-vegas-2
# ..                      ...                                             ...
# 995  Lau3N654yNyWdIIybea1uA                          il-fornaio-las-vegas-4
# 996  joKG-MSwMJdR_OFm4J1WTA                             le-thai-2-las-vegas
# 997  Y7swVZkYN021qBBy9ItjXA  meowee-wowee-hawaiian-shave-ice-cafe-las-vegas
# 998  HykZIiaHS35N2c5_QHoClA                      manna-korean-bbq-las-vegas
# 999  eZcCFV-8X91ZSnmB9807bw              the-cheesecake-factory-las-vegas-4
#
#                                      name  \
# ...

# %%
FinalYelpDF = yelpDF1.append([yelpDF2,yelpDF3,yelpDF4])
FinalYelpDF
# Out:
#                          id                                           alias  \
# 0    RVQE2Z2uky4c0-njFQO66g                    midwood-smokehouse-charlotte
# 1    RAh9WCQAuocM7hYM5_6tnw          the-cowfish-sushi-burger-bar-charlotte
# 2    sdYkVaTy7EJwUkO8Ie_qPg                          viva-chicken-charlotte
# 3    gG9z6zr_49LocyCTvSFg0w     amélies-french-bakery-and-café-charlotte-11
# 4    NFm869_w6cvVaWaNpAzjeA                     soul-gastrolounge-charlotte
# ..                      ...                                             ...
# 995  Lau3N654yNyWdIIybea1uA                          il-fornaio-las-vegas-4
# 996  joKG-MSwMJdR_OFm4J1WTA                             le-thai-2-las-vegas
# 997  Y7swVZkYN021qBBy9ItjXA  meowee-wowee-hawaiian-shave-ice-cafe-las-vegas
# 998  HykZIiaHS35N2c5_QHoClA                      manna-korean-bbq-las-vegas
# 999  eZcCFV-8X91ZSnmB9807bw              the-cheesecake-factory-las-vegas-4
#
#                                      name  \
# ...

# %%
FinalYelpDF = FinalYelpDF.reset_index(drop = True)
FinalYelpDF
# Out:
#                           id                                           alias  \
# 0     RVQE2Z2uky4c0-njFQO66g                    midwood-smokehouse-charlotte
# 1     RAh9WCQAuocM7hYM5_6tnw          the-cowfish-sushi-burger-bar-charlotte
# 2     sdYkVaTy7EJwUkO8Ie_qPg                          viva-chicken-charlotte
# 3     gG9z6zr_49LocyCTvSFg0w     amélies-french-bakery-and-café-charlotte-11
# 4     NFm869_w6cvVaWaNpAzjeA                     soul-gastrolounge-charlotte
# ...                      ...                                             ...
# 3995  Lau3N654yNyWdIIybea1uA                          il-fornaio-las-vegas-4
# 3996  joKG-MSwMJdR_OFm4J1WTA                             le-thai-2-las-vegas
# 3997  Y7swVZkYN021qBBy9ItjXA  meowee-wowee-hawaiian-shave-ice-cafe-las-vegas
# 3998  HykZIiaHS35N2c5_QHoClA                      manna-korean-bbq-las-vegas
# 3999  eZcCFV-8X91ZSnmB9807bw              the-cheesecake-factory-las-vegas-4
#
# ...

# %%
FinalYelpDF2 = FinalYelpDF.rename(columns={"id" : "business_id"})
FinalYelpDF2
# Out:
#                  business_id                                           alias  \
# 0     RVQE2Z2uky4c0-njFQO66g                    midwood-smokehouse-charlotte
# 1     RAh9WCQAuocM7hYM5_6tnw          the-cowfish-sushi-burger-bar-charlotte
# 2     sdYkVaTy7EJwUkO8Ie_qPg                          viva-chicken-charlotte
# 3     gG9z6zr_49LocyCTvSFg0w     amélies-french-bakery-and-café-charlotte-11
# 4     NFm869_w6cvVaWaNpAzjeA                     soul-gastrolounge-charlotte
# ...                      ...                                             ...
# 3995  Lau3N654yNyWdIIybea1uA                          il-fornaio-las-vegas-4
# 3996  joKG-MSwMJdR_OFm4J1WTA                             le-thai-2-las-vegas
# 3997  Y7swVZkYN021qBBy9ItjXA  meowee-wowee-hawaiian-shave-ice-cafe-las-vegas
# 3998  HykZIiaHS35N2c5_QHoClA                      manna-korean-bbq-las-vegas
# 3999  eZcCFV-8X91ZSnmB9807bw              the-cheesecake-factory-las-vegas-4
#
# ...

# %%
FinalYelpDF3 = FinalYelpDF2[["business_id", "name", "is_closed", "categories", "rating", "location.city", "location.state"]] 
FinalYelpDF3
# Out:
#                  business_id                                  name  is_closed  \
# 0     RVQE2Z2uky4c0-njFQO66g                    Midwood Smokehouse      False
# 1     RAh9WCQAuocM7hYM5_6tnw          The Cowfish Sushi Burger Bar      False
# 2     sdYkVaTy7EJwUkO8Ie_qPg                          Viva Chicken      False
# 3     gG9z6zr_49LocyCTvSFg0w         Amélie's French Bakery & Café      False
# 4     NFm869_w6cvVaWaNpAzjeA                     Soul Gastrolounge      False
# ...                      ...                                   ...        ...
# 3995  Lau3N654yNyWdIIybea1uA                            Il Fornaio      False
# 3996  joKG-MSwMJdR_OFm4J1WTA                             Le Thai 2      False
# 3997  Y7swVZkYN021qBBy9ItjXA  Meowee Wowee Hawaiian Shave Ice Cafe      False
# 3998  HykZIiaHS35N2c5_QHoClA                      Manna Korean BBQ      False
# 3999  eZcCFV-8X91ZSnmB9807bw                The Cheesecake Factory      False
#
# ...

# %%
# response = requests.get(url, headers = header)
# data = yelpDF
# alias = []
# business_id = []
# city = []
# is_closed = []
# rating = []
# categories = []

# for i in range(len(data)):
#     alias.append(data[i]["alias"])
#     business_id.append(data[i]["id"])
#     city.append(data[i]["location"]["city"])
#     is_closed.append(data[i]["is_closed"])
#     rating.append(data[i]["rating"])
#     categories.append(data[i]["categories"][0]["alias"])
    
# columns = {"Restaurant Name": alias, "business_id": business_id, "City": city, "Closed": is_closed, "Rating": rating, "Category": categories}

# restaurantDF = pd.DataFrame(columns)

# restaurantDF

# %%
covid_df = pd.read_csv('/Users/kylethomasmataloni/Desktop/covidrestaurant.csv')
covid_df
# Out:
#        Unnamed: 0             business_id highlights  delivery or takeout  \
# 0               2  FYddq7fUtzobZcw4jOJgVA      FALSE                False
# 1               3  c75jLTjlgA9q3gImLEGT6w      FALSE                False
# 2               9  64ZUb-llBHrnOcN_o1wA_A      FALSE                 True
# 3              12  9tK5ibv58TxxpndehLXjDg      FALSE                False
# 4              20  MU8xA_S8gqobnDq8d2nsQg      FALSE                False
# ...           ...                     ...        ...                  ...
# 28870      209738  JK15rhxmwItlU7Tb5jPooA      FALSE                False
# 28871      209755  PIJc0HWZaf7St_T_4L9tZg      FALSE                 True
# 28872      209757  57aBx6Mo_VRk_kMA8J5Efg      FALSE                 True
# 28873      209765  vAyQDNs9lu_8hT20lleGqg      FALSE                 True
# 28874      209774                  #NAME?      FALSE                False
#
#        Grubhub enabled  Call To Action enabled  Request a Quote Enabled  \
# ...

# %%
# data_file = open("yelp_academic_dataset_covid_features.json")
# data = []
# for line in data_file:
#     data.append(json.loads(line))
    
# covid_df = pd.DataFrame(data)

# data_file.close()

# covid_df

# %%
merge_df = pd.merge(FinalYelpDF3, covid_df, on="business_id", how="right")
merge_df
# Out:
#                   business_id                   name is_closed  \
# 0      FYddq7fUtzobZcw4jOJgVA                    NaN       NaN
# 1      c75jLTjlgA9q3gImLEGT6w                    NaN       NaN
# 2      64ZUb-llBHrnOcN_o1wA_A                    NaN       NaN
# 3      9tK5ibv58TxxpndehLXjDg                    NaN       NaN
# 4      MU8xA_S8gqobnDq8d2nsQg                    NaN       NaN
# ...                       ...                    ...       ...
# 28870  iAu8s96GKQ73Xe7j_2GyCQ  Jackson's Bar & Grill     False
# 28871  JK15rhxmwItlU7Tb5jPooA                    NaN       NaN
# 28872  PIJc0HWZaf7St_T_4L9tZg                    NaN       NaN
# 28873  57aBx6Mo_VRk_kMA8J5Efg                    NaN       NaN
# 28874  vAyQDNs9lu_8hT20lleGqg                    NaN       NaN
#
#                                               categories  rating  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# ...

# %%
RestaurantNotNull = pd.notnull(merge_df["name"])
YelpCovidDF = merge_df[RestaurantNotNull]
YelpCovidDF
# Out:
#                   business_id                     name is_closed  \
# 2889   Q6nhycv6JGREujknLYz2wg               Someburros     False
# 2923   gn9cc6-VLuCClqkWCtNcpg  Mi Pueblo Mexican Grill     False
# 2977   EPBEz9ifFo6JqPUUH_BdMg        Thai Thai Takeout     False
# 3188   sjiTzC2aoy13iPuIvk37Ew              Jet's Pizza     False
# 3200   QDqn9XWn_B-Rbc0DDMEljw               Yummy Crab     False
# ...                       ...                      ...       ...
# 28794  3MntE_HWbNNoyiLGxywjYA            Toppers Pizza     False
# 28846  JvCuy7FEZoiZ-7cABfHKSA           PT Pho Express     False
# 28860  AjWFFZN8KwyqJzzi0DyEsw         Burger Brasserie     False
# 28867  _mg5bYknpZgaWSfjQVmrJQ       Spinato's Pizzeria     False
# 28870  iAu8s96GKQ73Xe7j_2GyCQ    Jackson's Bar & Grill     False
#
#                                               categories  rating  \
# 2889   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
# ...

# %%
# rename column headers and pull out alias in categories -- ["categories"][0]["alias"]?

# %%
pd.json_normalize(YelpCovidDF["categories"].iloc[0])
# Out:
#               alias               title
# 0           mexican             Mexican
# 1  breakfast_brunch  Breakfast & Brunch

# %%
YelpCovidDF['alias']=YelpCovidDF['categories'].apply(lambda x: x[0]['alias'])
YelpCovidDF['title']=YelpCovidDF['categories'].apply(lambda x: x[0]['title'])
# Out:
# <ipython-input-38-ca89c92428de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   YelpCovidDF['alias']=YelpCovidDF['categories'].apply(lambda x: x[0]['alias'])
# <ipython-input-38-ca89c92428de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   YelpCovidDF['title']=YelpCovidDF['categories'].apply(lambda x: x[0]['title'])

# %%
YelpCovidDF
# Out:
#                   business_id                     name is_closed  \
# 2889   Q6nhycv6JGREujknLYz2wg               Someburros     False
# 2923   gn9cc6-VLuCClqkWCtNcpg  Mi Pueblo Mexican Grill     False
# 2977   EPBEz9ifFo6JqPUUH_BdMg        Thai Thai Takeout     False
# 3188   sjiTzC2aoy13iPuIvk37Ew              Jet's Pizza     False
# 3200   QDqn9XWn_B-Rbc0DDMEljw               Yummy Crab     False
# ...                       ...                      ...       ...
# 28794  3MntE_HWbNNoyiLGxywjYA            Toppers Pizza     False
# 28846  JvCuy7FEZoiZ-7cABfHKSA           PT Pho Express     False
# 28860  AjWFFZN8KwyqJzzi0DyEsw         Burger Brasserie     False
# 28867  _mg5bYknpZgaWSfjQVmrJQ       Spinato's Pizzeria     False
# 28870  iAu8s96GKQ73Xe7j_2GyCQ    Jackson's Bar & Grill     False
#
#                                               categories  rating  \
# 2889   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
# ...

# %%
YelpCovidDF.drop(columns = "categories")
# Out:
#                   business_id                     name is_closed  rating  \
# 2889   Q6nhycv6JGREujknLYz2wg               Someburros     False     3.5
# 2923   gn9cc6-VLuCClqkWCtNcpg  Mi Pueblo Mexican Grill     False     3.5
# 2977   EPBEz9ifFo6JqPUUH_BdMg        Thai Thai Takeout     False     3.5
# 3188   sjiTzC2aoy13iPuIvk37Ew              Jet's Pizza     False     4.5
# 3200   QDqn9XWn_B-Rbc0DDMEljw               Yummy Crab     False     3.5
# ...                       ...                      ...       ...     ...
# 28794  3MntE_HWbNNoyiLGxywjYA            Toppers Pizza     False     3.5
# 28846  JvCuy7FEZoiZ-7cABfHKSA           PT Pho Express     False     4.0
# 28860  AjWFFZN8KwyqJzzi0DyEsw         Burger Brasserie     False     3.5
# 28867  _mg5bYknpZgaWSfjQVmrJQ       Spinato's Pizzeria     False     4.0
# 28870  iAu8s96GKQ73Xe7j_2GyCQ    Jackson's Bar & Grill     False     4.0
#
#       location.city location.state  Unnamed: 0  \
# ...
